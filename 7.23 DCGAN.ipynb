# %%
from keras.datasets import mnist
from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.layers import BatchNormalization, Activation, LeakyReLU
from keras.layers import UpSampling2D, Conv2D
from keras.models import Sequential, Model
import numpy as np
import matplotlib.pyplot as plt

g = Sequential()
g.add(Dense(input_dim=100, units=7*7*128, activation=LeakyReLU(0.2)))
g.add(BatchNormalization())
g.add(Reshape((7, 7, 128)))
g.add(UpSampling2D())
g.add(Conv2D(filters=128, 
             kernel_size=3, # kernel_size=(3,3)
             padding='Same'))
g.add(BatchNormalization())
g.add(Activation(LeakyReLU(0.2)))
g.add(UpSampling2D())
g.add(Conv2D(filters=1, 
             kernel_size=3,
             padding='Same',
             activation='tanh'))

d = Sequential()
d.add(Conv2D(filters=64, 
             kernel_size=3,
             padding='Same',
             input_shape=(28, 28, 1),
             strides=2))
d.add(Activation(LeakyReLU(0.2)))
d.add(Dropout(0.3))
d.add(Conv2D(filters=64, 
             kernel_size=3,
             padding='Same',
             strides=2))
d.add(Activation(LeakyReLU(0.2)))
d.add(Dropout(0.3))
d.add(Flatten())
d.add(Dense(units=1, activation='sigmoid'))
d.compile(loss='binary_crossentropy', optimizer='adam')
d.trainable=False

gan_input = Input(shape=(100,))
h = g(gan_input)
gan_output = d(h)
gan = Model(gan_input, gan_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')

def gan_train(epoch, batch_size, save_interval):
    (X_train, y_train), (X_test, y_test) = mnist.load_data()
    X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
    X_train = (X_train-127.5)/127.5
    true_label = np.ones((batch_size, 1))
    fake_label = np.zeros((batch_size, 1))
    
    for e in range(epoch):
        true_data = X_train[np.random.randint(0, X_train.shape[0], batch_size)]
        d_loss_true = d.train_on_batch(true_data, true_label)
        
        noise = np.random.normal(0, 1, size=(batch_size, 100))
        fake_data = g.predict(noise)
        d_loss_fake = d.train_on_batch(fake_data, fake_label)
        
        d_loss = 0.5 * np.add(d_loss_true, d_loss_fake)
        
        g_loss = gan.train_batch(noise, true_label)
        
        print('Epoch :', e+1, '\tD_LOSS :', round(d_loss, 4),
              '\tG_LOSS :', round(g_loss, 4))
        
        if e % save_interval == 0:
            noise = np.random.normal(0, 1, size=(25, 100))
            imgs = g.predict(noise)
            imgs = 0.5 * imgs + 0.5
            
            fig, ax = plt.subplots(5, 5)
            num_of_imgs = 0
            for i in range(5):
                for j in range(5):
                    axs[i, j].imshow(imgs[num_of_imgs, :, :, 0], cmap='gray')
                    axs[i, j].axis('off')
                    num_of_imgs += 1

# %%
from keras.datasets import mnist
from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.layers import BatchNormalization, Activation, LeakyReLU
from keras.layers import UpSampling2D, Conv2D
from keras.models import Sequential, Model
import numpy as np
import matplotlib.pyplot as plt

g = Sequential()
g.add(Dense(input_dim=100, units=7*7*128, activation=LeakyReLU(0.2)))
g.add(BatchNormalization())
g.add(Reshape((7, 7, 128)))
g.add(UpSampling2D())
g.add(Conv2D(filters=128, kernel_size=3, padding="Same"))
g.add(BatchNormalization())
g.add(Activation(LeakyReLU(0.2)))
g.add(UpSampling2D())
g.add(Conv2D(filters=1, kernel_size=3, padding="Same", activation="tanh"))

d = Sequential()
d.add(Conv2D(filters=64, kernel_size=3, padding="Same", \
             input_shape=(28, 28, 1), strides=2))
d.add(Activation(LeakyReLU(0.2)))
d.add(Dropout(0.3))
d.add(Conv2D(filters=64, kernel_size=3, padding="Same", strides=2))
d.add(Activation(LeakyReLU(0.2)))
d.add(Dropout(0.3))
d.add(Flatten())
d.add(Dense(units=1, activation="sigmoid"))
d.compile(loss="binary_crossentropy", optimizer="adam")
d.trainable = False

gan_input = Input(shape=(100,))
h = g(gan_input)
gan_output = d(h)
gan = Model(gan_input, gan_output)
gan.compile(loss="binary_crossentropy", optimizer="adam")

def gan_train(epoch, batch_size, save_interval):
    (X_train, _), (_, _) = mnist.load_data()
    X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype("float32")
    X_train = (X_train - 127.5) / 127.5
    true_label = np.ones((batch_size, 1))
    fake_label = np.zeros((batch_size, 1))
    
    for e in range(epoch):
        true_data = X_train[np.random.randint(0, X_train.shape[0], batch_size)]
        d_loss_true = d.train_on_batch(true_data, true_label)
        
        noise = np.random.normal(0, 1, size=(batch_size, 100))
        fake_data = g.predict(noise)
        d_loss_fake = d.train_on_batch(fake_data, fake_label)
        
        d_loss = 0.5 * np.add(d_loss_true, d_loss_fake)
        
        g_loss = gan.train_on_batch(noise, true_label)
        
        print("Epoch :", e+1, "\tD_LOSS :", round(d_loss, 4), \
             "\tG_LOSS :", round(g_loss, 4))

        if e % save_interval == 0:
            noise = np.random.normal(0, 1, size=(25, 100))
            imgs = g.predict(noise)
            imgs = 0.5 * imgs + 0.5
            
            fig, axs = plt.subplots(5, 5)
            num_of_imgs = 0
            for i in range(5):
                for j in range(5):
                    axs[i, j].imshow(imgs[num_of_imgs, :, :, 0], cmap="gray")
                    axs[i, j].axis("off")
                    num_of_imgs += 1

# %%
gan_train(500, 128, 100)
# Out:
# C:\anaconda\envs\test3\lib\site-packages\keras\engine\training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# WARNING:tensorflow:From C:\anaconda\envs\test3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# C:\anaconda\envs\test3\lib\site-packages\keras\engine\training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Epoch : 1 	D_LOSS : 0.7199 	G_LOSS : 0.6167
# C:\anaconda\envs\test3\lib\site-packages\keras\engine\training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Epoch : 2 	D_LOSS : 0.5999 	G_LOSS : 0.4637
# Epoch : 3 	D_LOSS : 0.5372 	G_LOSS : 0.2887
# Epoch : 4 	D_LOSS : 0.5086 	G_LOSS : 0.1483
# Epoch : 5 	D_LOSS : 0.5153 	G_LOSS : 0.0753
# Epoch : 6 	D_LOSS : 0.5343 	G_LOSS : 0.0519
# Epoch : 7 	D_LOSS : 0.5515 	G_LOSS : 0.0504
# Epoch : 8 	D_LOSS : 0.5556 	G_LOSS : 0.0695
# Epoch : 9 	D_LOSS : 0.545 	G_LOSS : 0.1053
# Epoch : 10 	D_LOSS : 0.5255 	G_LOSS : 0.1649
# Epoch : 11 	D_LOSS : 0.5047 	G_LOSS : 0.2591
# Epoch : 12 	D_LOSS : 0.49 	G_LOSS : 0.3615
# Epoch : 13 	D_LOSS : 0.4766 	G_LOSS : 0.4581
# Epoch : 14 	D_LOSS : 0.4626 	G_LOSS : 0.5843
# Epoch : 15 	D_LOSS : 0.4593 	G_LOSS : 0.6846
# Epoch : 259 	D_LOSS : 0.7643 	G_LOSS : 0.8078
# Epoch : 260 	D_LOSS : 0.7457 	G_LOSS : 0.7716
# Epoch : 261 	D_LOSS : 0.7673 	G_LOSS : 0.7849
# Epoch : 262 	D_LOSS : 0.7222 	G_LOSS : 0.8355
# Epoch : 263 	D_LOSS : 0.7302 	G_LOSS : 0.8375
# Epoch : 264 	D_LOSS : 0.7202 	G_LOSS : 0.8524
# Epoch : 265 	D_LOSS : 0.6915 	G_LOSS : 0.8639
# Epoch : 266 	D_LOSS : 0.7103 	G_LOSS : 0.8922
# Epoch : 267 	D_LOSS : 0.7085 	G_LOSS : 0.9219
# Epoch : 268 	D_LOSS : 0.6871 	G_LOSS : 0.9233
# Epoch : 269 	D_LOSS : 0.6909 	G_LOSS : 0.9274
# Epoch : 270 	D_LOSS : 0.6862 	G_LOSS : 0.9308
# Epoch : 271 	D_LOSS : 0.6727 	G_LOSS : 0.9038
# Epoch : 272 	D_LOSS : 0.6509 	G_LOSS : 0.9548
# Epoch : 273 	D_LOSS : 0.6714 	G_LOSS : 0.9131
# Epoch : 274 	D_LOSS : 0.6542 	G_LOSS : 0.907
# Epoch : 275 	D_LOSS : 0.6587 	G_LOSS : 0.9428
# Epoch : 276 	D_LOSS : 0.6372 	G_LOSS : 0.9196
# Epoch : 277 	D_LOSS : 0.6503 	G_LOSS : 0.9138
# Epoch : 278 	D_LOSS : 0.6486 	G_LOSS : 0.9142
# Epoch : 279 	D_LOSS : 0.6196 	G_LOSS : 0.9538
# Epoch : 280 	D_LOSS : 0.6294 	G_LOSS : 0.937
# Epoch : 281 	D_LOSS : 0.6372 	G_LOSS : 0.9523
# Epoch : 282 	D_LOSS : 0.6272 	G_LOSS : 0.9381
# Epoch : 283 	D_LOSS : 0.6009 	G_LOSS : 0.9812
# Epoch : 284 	D_LOSS : 0.6218 	G_LOSS : 0.9456
# Epoch : 285 	D_LOSS : 0.6272 	G_LOSS : 0.9494
# Epoch : 286 	D_LOSS : 0.6136 	G_LOSS : 0.9475
# Epoch : 287 	D_LOSS : 0.6121 	G_LOSS : 0.9302
# Epoch : 288 	D_LOSS : 0.5811 	G_LOSS : 0.9511
# Epoch : 289 	D_LOSS : 0.6327 	G_LOSS : 0.8672
# Epoch : 290 	D_LOSS : 0.6021 	G_LOSS : 0.9146
# Epoch : 291 	D_LOSS : 0.5923 	G_LOSS : 0.9093
# Epoch : 292 	D_LOSS : 0.6281 	G_LOSS : 0.8009
# Epoch : 293 	D_LOSS : 0.6292 	G_LOSS : 0.8461
# Epoch : 294 	D_LOSS : 0.6447 	G_LOSS : 0.8211
# Epoch : 295 	D_LOSS : 0.6715 	G_LOSS : 0.7979
# Epoch : 296 	D_LOSS : 0.6938 	G_LOSS : 0.7678
# Epoch : 297 	D_LOSS : 0.6431 	G_LOSS : 0.7528
# Epoch : 298 	D_LOSS : 0.6607 	G_LOSS : 0.7564
# Epoch : 299 	D_LOSS : 0.7356 	G_LOSS : 0.7021
# Epoch : 300 	D_LOSS : 0.7381 	G_LOSS : 0.6683
# Epoch : 301 	D_LOSS : 0.7748 	G_LOSS : 0.6679
# Epoch : 302 	D_LOSS : 0.7893 	G_LOSS : 0.6585
# Epoch : 303 	D_LOSS : 0.8124 	G_LOSS : 0.5775
# Epoch : 304 	D_LOSS : 0.851 	G_LOSS : 0.5878
# Epoch : 305 	D_LOSS : 0.8078 	G_LOSS : 0.6074
# Epoch : 306 	D_LOSS : 0.822 	G_LOSS : 0.6023
# Epoch : 307 	D_LOSS : 0.8566 	G_LOSS : 0.5973
# Epoch : 308 	D_LOSS : 0.8312 	G_LOSS : 0.617
# Epoch : 309 	D_LOSS : 0.8474 	G_LOSS : 0.6221
# Epoch : 310 	D_LOSS : 0.8052 	G_LOSS : 0.6254
# Epoch : 311 	D_LOSS : 0.8171 	G_LOSS : 0.6538
# Epoch : 312 	D_LOSS : 0.7913 	G_LOSS : 0.6731
# Epoch : 313 	D_LOSS : 0.7738 	G_LOSS : 0.7166
# Epoch : 314 	D_LOSS : 0.7513 	G_LOSS : 0.7599
# Epoch : 315 	D_LOSS : 0.7359 	G_LOSS : 0.795
# Epoch : 316 	D_LOSS : 0.6843 	G_LOSS : 0.8887
# Epoch : 317 	D_LOSS : 0.6591 	G_LOSS : 0.9831
# Epoch : 318 	D_LOSS : 0.5962 	G_LOSS : 1.0573
# Epoch : 319 	D_LOSS : 0.5402 	G_LOSS : 1.2315
# Epoch : 320 	D_LOSS : 0.4927 	G_LOSS : 1.2761
# Epoch : 321 	D_LOSS : 0.4314 	G_LOSS : 1.516
# Epoch : 322 	D_LOSS : 0.3978 	G_LOSS : 1.6699
# Epoch : 323 	D_LOSS : 0.314 	G_LOSS : 1.8774
# Epoch : 324 	D_LOSS : 0.289 	G_LOSS : 2.0344
# Epoch : 325 	D_LOSS : 0.2746 	G_LOSS : 2.259
# Epoch : 326 	D_LOSS : 0.281 	G_LOSS : 2.292
# Epoch : 327 	D_LOSS : 0.3189 	G_LOSS : 2.2345
# Epoch : 328 	D_LOSS : 0.3343 	G_LOSS : 2.1844
# Epoch : 329 	D_LOSS : 0.4561 	G_LOSS : 2.0605
# Epoch : 330 	D_LOSS : 0.4966 	G_LOSS : 2.1883
# Epoch : 331 	D_LOSS : 0.7525 	G_LOSS : 1.6945
# Epoch : 332 	D_LOSS : 0.9079 	G_LOSS : 1.45
# Epoch : 333 	D_LOSS : 1.0545 	G_LOSS : 1.0721
# Epoch : 334 	D_LOSS : 1.0914 	G_LOSS : 0.9314
# Epoch : 335 	D_LOSS : 1.0537 	G_LOSS : 0.9381
# Epoch : 336 	D_LOSS : 1.2974 	G_LOSS : 0.8621
# Epoch : 337 	D_LOSS : 1.1669 	G_LOSS : 0.826
# Epoch : 338 	D_LOSS : 1.2364 	G_LOSS : 0.6757
# Epoch : 339 	D_LOSS : 1.1992 	G_LOSS : 0.5194
# Epoch : 380 	D_LOSS : 0.5188 	G_LOSS : 1.0235
# Epoch : 381 	D_LOSS : 0.5742 	G_LOSS : 0.939
# Epoch : 382 	D_LOSS : 0.6164 	G_LOSS : 0.911
# Epoch : 383 	D_LOSS : 0.6317 	G_LOSS : 0.8219
# Epoch : 384 	D_LOSS : 0.7158 	G_LOSS : 0.815
# Epoch : 385 	D_LOSS : 0.6747 	G_LOSS : 0.7466
# Epoch : 386 	D_LOSS : 0.729 	G_LOSS : 0.7037
# Epoch : 387 	D_LOSS : 0.827 	G_LOSS : 0.6075
# Epoch : 388 	D_LOSS : 0.8184 	G_LOSS : 0.6034
# Epoch : 389 	D_LOSS : 0.772 	G_LOSS : 0.5843
# Epoch : 390 	D_LOSS : 0.8806 	G_LOSS : 0.5951
# Epoch : 391 	D_LOSS : 0.8241 	G_LOSS : 0.5465
# Epoch : 392 	D_LOSS : 0.8876 	G_LOSS : 0.5483
# Epoch : 393 	D_LOSS : 0.8726 	G_LOSS : 0.5523
# Epoch : 394 	D_LOSS : 0.8258 	G_LOSS : 0.5344
# Epoch : 395 	D_LOSS : 0.8303 	G_LOSS : 0.565
# Epoch : 396 	D_LOSS : 0.8219 	G_LOSS : 0.5984
# Epoch : 397 	D_LOSS : 0.7503 	G_LOSS : 0.6246
# Epoch : 398 	D_LOSS : 0.8225 	G_LOSS : 0.6322
# Epoch : 399 	D_LOSS : 0.7755 	G_LOSS : 0.6573
# Epoch : 400 	D_LOSS : 0.7447 	G_LOSS : 0.6788
# Epoch : 401 	D_LOSS : 0.7084 	G_LOSS : 0.7196
# Epoch : 402 	D_LOSS : 0.7218 	G_LOSS : 0.6921
# Epoch : 403 	D_LOSS : 0.6914 	G_LOSS : 0.7388
# Epoch : 404 	D_LOSS : 0.6871 	G_LOSS : 0.7536
# Epoch : 405 	D_LOSS : 0.6518 	G_LOSS : 0.7872
# Epoch : 406 	D_LOSS : 0.6379 	G_LOSS : 0.8101
# Epoch : 407 	D_LOSS : 0.6192 	G_LOSS : 0.8766
# Epoch : 408 	D_LOSS : 0.5987 	G_LOSS : 0.9426
# Epoch : 409 	D_LOSS : 0.5787 	G_LOSS : 1.0569
# Epoch : 410 	D_LOSS : 0.5285 	G_LOSS : 1.2141
# Epoch : 411 	D_LOSS : 0.5206 	G_LOSS : 1.3838
# Epoch : 412 	D_LOSS : 0.4976 	G_LOSS : 1.5015
# Epoch : 413 	D_LOSS : 0.4681 	G_LOSS : 1.66
# Epoch : 414 	D_LOSS : 0.4402 	G_LOSS : 1.8377
# Epoch : 415 	D_LOSS : 0.4123 	G_LOSS : 1.7789
# Epoch : 416 	D_LOSS : 0.3895 	G_LOSS : 1.7678
# Epoch : 417 	D_LOSS : 0.3711 	G_LOSS : 1.8084
# Epoch : 418 	D_LOSS : 0.3807 	G_LOSS : 1.8162
# Epoch : 419 	D_LOSS : 0.3768 	G_LOSS : 1.7915
# Epoch : 420 	D_LOSS : 0.4533 	G_LOSS : 1.7032
# Epoch : 421 	D_LOSS : 0.3493 	G_LOSS : 2.047
# Epoch : 422 	D_LOSS : 0.4048 	G_LOSS : 2.0444
# Epoch : 423 	D_LOSS : 0.3821 	G_LOSS : 2.1449
# Epoch : 424 	D_LOSS : 0.4375 	G_LOSS : 2.1556
# Epoch : 425 	D_LOSS : 0.4622 	G_LOSS : 1.9552
# Epoch : 426 	D_LOSS : 0.542 	G_LOSS : 1.769
# Epoch : 427 	D_LOSS : 0.6434 	G_LOSS : 1.6282
# Epoch : 428 	D_LOSS : 0.6602 	G_LOSS : 1.3032
# Epoch : 429 	D_LOSS : 0.7328 	G_LOSS : 1.2325
# Epoch : 430 	D_LOSS : 0.7403 	G_LOSS : 1.2561
# Epoch : 431 	D_LOSS : 0.8833 	G_LOSS : 1.1401
# Epoch : 432 	D_LOSS : 0.7926 	G_LOSS : 1.0774
# Epoch : 433 	D_LOSS : 0.9719 	G_LOSS : 0.9353
# Epoch : 434 	D_LOSS : 0.9363 	G_LOSS : 0.8125
# Epoch : 435 	D_LOSS : 0.9485 	G_LOSS : 0.7919
# Epoch : 436 	D_LOSS : 0.9157 	G_LOSS : 0.7235
# Epoch : 437 	D_LOSS : 0.9077 	G_LOSS : 0.763
# Epoch : 438 	D_LOSS : 0.7878 	G_LOSS : 0.7906
# Epoch : 439 	D_LOSS : 0.7651 	G_LOSS : 0.8379
# Epoch : 440 	D_LOSS : 0.7693 	G_LOSS : 0.822
# Epoch : 441 	D_LOSS : 0.7187 	G_LOSS : 0.8674
# Epoch : 442 	D_LOSS : 0.6733 	G_LOSS : 0.8655
# Epoch : 443 	D_LOSS : 0.6208 	G_LOSS : 0.9396
# Epoch : 444 	D_LOSS : 0.5782 	G_LOSS : 0.9582
# Epoch : 445 	D_LOSS : 0.5803 	G_LOSS : 1.0551
# Epoch : 446 	D_LOSS : 0.5182 	G_LOSS : 1.1271
# Epoch : 447 	D_LOSS : 0.5221 	G_LOSS : 1.2102
# Epoch : 448 	D_LOSS : 0.5009 	G_LOSS : 1.2592
# Epoch : 449 	D_LOSS : 0.4926 	G_LOSS : 1.2959
# Epoch : 450 	D_LOSS : 0.4536 	G_LOSS : 1.3628
# Epoch : 451 	D_LOSS : 0.4787 	G_LOSS : 1.3514
# Epoch : 452 	D_LOSS : 0.4903 	G_LOSS : 1.3499
# Epoch : 453 	D_LOSS : 0.4657 	G_LOSS : 1.3753
# Epoch : 454 	D_LOSS : 0.4561 	G_LOSS : 1.3356
# Epoch : 455 	D_LOSS : 0.4596 	G_LOSS : 1.3388
# Epoch : 456 	D_LOSS : 0.4497 	G_LOSS : 1.3328
# Epoch : 457 	D_LOSS : 0.4592 	G_LOSS : 1.3041
# Epoch : 458 	D_LOSS : 0.4404 	G_LOSS : 1.3083
# Epoch : 459 	D_LOSS : 0.4386 	G_LOSS : 1.2875
# Epoch : 460 	D_LOSS : 0.4363 	G_LOSS : 1.3041
# Epoch : 461 	D_LOSS : 0.439 	G_LOSS : 1.3062
# Epoch : 462 	D_LOSS : 0.4204 	G_LOSS : 1.3132
# Epoch : 463 	D_LOSS : 0.4004 	G_LOSS : 1.3773
# Epoch : 464 	D_LOSS : 0.4195 	G_LOSS : 1.4035
# Epoch : 465 	D_LOSS : 0.3942 	G_LOSS : 1.3942
# Epoch : 466 	D_LOSS : 0.3929 	G_LOSS : 1.4259
# Epoch : 467 	D_LOSS : 0.3972 	G_LOSS : 1.4356
# Epoch : 468 	D_LOSS : 0.4034 	G_LOSS : 1.4807
# Epoch : 469 	D_LOSS : 0.3956 	G_LOSS : 1.4514
# Epoch : 470 	D_LOSS : 0.3965 	G_LOSS : 1.5112
# Epoch : 471 	D_LOSS : 0.3844 	G_LOSS : 1.4498
# Epoch : 472 	D_LOSS : 0.3672 	G_LOSS : 1.4968
# Epoch : 473 	D_LOSS : 0.3945 	G_LOSS : 1.4312
# Epoch : 474 	D_LOSS : 0.3866 	G_LOSS : 1.5582
# Epoch : 475 	D_LOSS : 0.3935 	G_LOSS : 1.5009
# Epoch : 476 	D_LOSS : 0.3797 	G_LOSS : 1.5032
# Epoch : 477 	D_LOSS : 0.3844 	G_LOSS : 1.5308
# Epoch : 478 	D_LOSS : 0.3763 	G_LOSS : 1.543
# Epoch : 479 	D_LOSS : 0.3713 	G_LOSS : 1.6315
# Epoch : 480 	D_LOSS : 0.3572 	G_LOSS : 1.6877
# Epoch : 481 	D_LOSS : 0.3923 	G_LOSS : 1.5505
# Epoch : 482 	D_LOSS : 0.4146 	G_LOSS : 1.56
# Epoch : 483 	D_LOSS : 0.3863 	G_LOSS : 1.5654
# Epoch : 484 	D_LOSS : 0.4291 	G_LOSS : 1.4825
# Epoch : 485 	D_LOSS : 0.4516 	G_LOSS : 1.4806
# Epoch : 486 	D_LOSS : 0.376 	G_LOSS : 1.5786
# Epoch : 487 	D_LOSS : 0.4055 	G_LOSS : 1.5565
# Epoch : 488 	D_LOSS : 0.4512 	G_LOSS : 1.4937
# Epoch : 489 	D_LOSS : 0.4833 	G_LOSS : 1.4483
# Epoch : 490 	D_LOSS : 0.4737 	G_LOSS : 1.3049
# Epoch : 491 	D_LOSS : 0.4602 	G_LOSS : 1.3779
# Epoch : 492 	D_LOSS : 0.4956 	G_LOSS : 1.2972
# Epoch : 493 	D_LOSS : 0.5437 	G_LOSS : 1.2587
# Epoch : 494 	D_LOSS : 0.5209 	G_LOSS : 1.2347
# Epoch : 495 	D_LOSS : 0.5302 	G_LOSS : 1.3155
# Epoch : 496 	D_LOSS : 0.597 	G_LOSS : 1.1137
# Epoch : 497 	D_LOSS : 0.5864 	G_LOSS : 1.0953
# Epoch : 498 	D_LOSS : 0.6631 	G_LOSS : 1.1291
# Epoch : 499 	D_LOSS : 0.6097 	G_LOSS : 1.0586
# Epoch : 500 	D_LOSS : 0.678 	G_LOSS : 1.056
